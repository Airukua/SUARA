# %%
# !git clone https://github.com/Airukua/SUARA.git
# Out:
# Cloning into 'SUARA'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 107 (delta 30), reused 104 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 4.48 MiB | 12.65 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !python3 /content/SUARA/explore.py
# Out:
# [Dataset] mulai...
#   Loading dataset with cache directory: artifacts/dataset_cache
# ...
# README.md: 100% 488/488 [00:00<00:00, 2.28MB/s]
# Generating dataset wikipedia-id (/content/artifacts/dataset_cache/indonesian-nlp___wikipedia-id/default/0.0.0/518f9a8c7e17e058385fdb60a4f18977986759a3)
# ...
# data/train-00000-of-00001.parquet: 100% 311M/311M [00:01<00:00, 171MB/s]
# data/test-00000-of-00001.parquet: 100% 34.6M/34.6M [00:00<00:00, 42.7MB/s]
# ...
# Checksum Computation took 0.0 min
# Generating train split
# Generating train split: 100% 1301683/1301683 [00:01<00:00, 1104998.33 examples/s]
# Generating test split
# Generating test split: 100% 144632/144632 [00:00<00:00, 1078843.70 examples/s]
# All the splits matched successfully.
# Dataset wikipedia-id downloaded and prepared to /content/artifacts/dataset_cache/indonesian-nlp___wikipedia-id/default/0.0.0/518f9a8c7e17e058385fdb60a4f18977986759a3. Subsequent calls will reuse this data.
# [Dataset] selesai dalam 9.42s
#
# ...
